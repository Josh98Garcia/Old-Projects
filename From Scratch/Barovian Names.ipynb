# %%
from random import randrange
from IPython.display import clear_output

# %%
x = "Alek, Andrej, Anton, Balthazar, Bogan, Boris, Dargos, Darzin, Dragomir, Emeric, Falkon, Frederich, Franz, Gargosh, Gorek, Grygori, Hans, Harkus, Ivan, jirko, Kobal, Korga, Krystofor, Lazio, Livius, Marek, Miroslav, Nikolaj, Nimir, Oleg, Radovan, Radu, Seraz, Sergei, Stefan, Tural, Valentin, Vasily, Vladislav, Waltar, Yesper, Zsolt"
firstNamesM = [y.strip() for y in x.split(',')]
x = "Alana, Clavdia, Danya, Dezdrelda, Diavola, Dorina, Drasha, Drilvia, Elisabeta, Fatima, Grilsha, Isabella, Ivana, Jarzinka, Kala, Katerina, Kereza, Korina, Lavinia, Magda, Marta, Mathilda, Minodora, Mirabel, Miruna, Nimira, Nyanka, Olivenka, Ruxandra, Serina, Tereska, Valentina, Vasha, Victoria, Wensencia, Zondra"
firstNamesF = [y.strip() for y in x.split(',')]
x = "Alastroi, Antonovich, Barthos, Belasco, Cantemir, Dargovich, Diavolov, Diminski, Dilisnya, Drazkoi, Garvinski, Grejenko, Groza, Grygorovich, lvanovich, Janek, Karushkin, Konstantinovich, Krezkov, Krykski, Lansten, Lazarescu, Lukresh, Lipsiege, Martikov, Mironovich, Moldovar, Nikolovich, Nimirovich, Oronovich, Petrovich, Polensky, Radovich, Rilsky, Stefanovich, Strazni, Swilovich, Taltos, Targolov, Tyminski, Ulbrek, Ulrich, Vadu, Voltanescu, Zalenski, Zalken"
lastNamesM = [y.strip() for y in x.split(',')]
x = "Alastroi, Antonova, Barthos, Belasco, Cantemir, Dargova, Diavolov, Diminski, Dilisnya, Drazkoi, Garvinski, Grejenko, Groza, Grygorova, lvanova, Janek, Karushkin, Konstantinova, Krezkova, Krykski, Lansten, Lazarescu, Lukresh, Lipsiege, Martikova, Mironovna, Moldovar, Nikolova, Nimirova, Oronova, Petrovna, Polensky, Radova, Rilsky, Stefanova, Strazni, Swilova, Taltos, Targolova, Tyminski, Ulbrek, Ulrich, Vadu, Voltanescu, Zalenski, Zalken"
lastNamesF = [y.strip() for y in x.split(',')]
firstNames = firstNamesM + firstNamesF
lastNames = lastNamesM + lastNamesF
 
def name(g):
  if g=="m":
    print(firstNamesM[randrange(len(firstNamesM))] + " " + lastNamesM[randrange(len(lastNamesM))])
  elif g=="f":
    print(firstNamesF[randrange(len(firstNamesF))] + " " + lastNamesF[randrange(len(lastNamesF))])
  else:
    print("r: " + firstNames[randrange(len(firstNames))] + " " + lastNames[randrange(len(lastNames))])
    print("f: " + firstNamesF[randrange(len(firstNamesF))] + " " + lastNamesF[randrange(len(lastNamesF))])
    print("m: " + firstNamesM[randrange(len(firstNamesM))] + " " + lastNamesM[randrange(len(lastNamesM))])
 
def clear(g):
  if g=="c":
    clear_output()
    return ""
 
def n():
  gen = "c"
  pg = ""
  print(gen)
  while gen!="q":
 
    name(gen)
 
    gen = clear(gen)
 
    gen = input()
 
    if pg=="":
      r = randrange(3)
      if r<1:
        pg = "m"
      elif r>1:
        pg = "f"
      else:
        pg = "n"
 
    if gen=="":
      gen = pg
    else:
      pg = gen
  if (gen=="q"):
    return False
  gen = "c"
  pg = ""
  return True

# %%
a = True
while a:
  a = n()
# Out:
# Kala lvanova
# q
